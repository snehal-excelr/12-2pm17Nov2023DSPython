# %%
# !pip install tensorflow # Currently, the most famous deep learning library in the world is Google’s TensorFlow.
# TensorFlow is an open-source end-to-end platform for creating Machine Learning applications.
# It is a symbolic math library that uses dataflow and differentiable programming to perform various tasks focused on training and inference of deep neural networks.
# It allows developers to create machine learning applications using various tools, libraries, and community resources.

# %%
# !pip install keras

# %%
# Create your first MLP in Keras. Keras is a library built on top of Tensar flow. It is used to build NN as well as to optimize hyperparameter.
from keras.models import Sequential # In NN we are going to add components (i.e. hidden layers) one by one in sequential manner
from keras.layers import Dense
# Keras Dense layer is the layer that contains all the neurons that are deeply connected within themselves.
#This means that every neuron in the dense layer takes the input from all the other neurons of the previous layer.
import numpy as np

# %%
# fix random seed for reproducibility
#seed = 7
#np.random.seed(seed)
# load pima indians dataset
dataset = np.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
dataset.shape[0]
# Out:
# 768

# %%
# create model
model = Sequential()
model.add(Dense(20, input_dim=8,  activation='relu')) #1st layer
model.add(Dense(10,  activation='relu')) #2nd layer
model.add(Dense(10,  activation='relu')) #3rd layer
model.add(Dense(1, activation='sigmoid')) #4rd layer or output layer

# %%
# Compile model - establish connection between input, hidden and output layer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# binary_crossentropy - Computes the crossentropy metric between the labels and predictions.
# This is the crossentropy metric class to be used when there are only two label classes (0 and 1)
# https://stackoverflow.com/questions/51704808/what-is-the-difference-between-loss-accuracy-validation-loss-validation-accur
# https://stackoverflow.com/questions/34518656/how-to-interpret-loss-and-accuracy-for-a-machine-learning-model

# %%
# Fit the model
history = model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=10)
# Out:
# Epoch 1/250
# 52/52 [==============================] - 2s 13ms/step - loss: 1.3421 - accuracy: 0.5914 - val_loss: 0.7865 - val_accuracy: 0.6220
# Epoch 2/250
# 52/52 [==============================] - 1s 12ms/step - loss: 0.7305 - accuracy: 0.6420 - val_loss: 0.7560 - val_accuracy: 0.6102
# Epoch 3/250
# 52/52 [==============================] - 0s 6ms/step - loss: 0.7005 - accuracy: 0.6459 - val_loss: 0.8260 - val_accuracy: 0.6378
# Epoch 4/250
# 52/52 [==============================] - 1s 10ms/step - loss: 0.7204 - accuracy: 0.6342 - val_loss: 0.7430 - val_accuracy: 0.6654
# Epoch 5/250
# 52/52 [==============================] - 0s 8ms/step - loss: 0.6794 - accuracy: 0.6537 - val_loss: 0.7937 - val_accuracy: 0.6260
# Epoch 6/250
# 52/52 [==============================] - 0s 8ms/step - loss: 0.6413 - accuracy: 0.6595 - val_loss: 0.6904 - val_accuracy: 0.5827
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4759 - accuracy: 0.7734
# accuracy: 77.34%

# %%
(model.metrics_names[1], scores[1]*100)
# Out:
# ('accuracy', 77.34375)

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
